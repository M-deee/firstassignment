# %% [markdown]
# # My jupyter notebook on IBM Waston

# %% [markdown]
# **MAHMUD LAWAL**
#
#
# Data science

# %% [markdown]
# *I am interested in data science because its an intresting coursee*

# %% [markdown]
# ### My code would print "hi there"

# %%
print("hi there")
# Out:
# hi there

# %% [markdown]
# ![c.jfif](attachment:c.jfif)
#
#
#
# 1. First
#     1. second
#     4. third
#
#
#
# * first
#     * second
